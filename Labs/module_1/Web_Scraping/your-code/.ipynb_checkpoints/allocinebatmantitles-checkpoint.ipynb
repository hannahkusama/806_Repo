# %%
import requests as r

# %%
from bs4 import BeautifulSoup

# %%
url='http://www.allocine.fr/article/fichearticle_gen_carticle=18690706.html'

# %%
resp = r.get(url)

# %%
resp.text
# Out:
# '<!DOCTYPE html>\n<html lang="fr">\n<head>\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n    <meta name="robots" content="index,follow,max-snippet:-1,max-image-preview:large,max-video-preview:5" />\n    <link rel="amphtml" href="http://www.allocine.fr/amp/article/fichearticle_gen_carticle=18690706.html">\n    <title>15 ans de Batman Begins : comment Christopher Nolan a sauvé l\'Homme Chauve-Souris - Actus Ciné - AlloCiné</title>\n    <meta name="keywords" content="" />\n    <meta name="Googlebot" content="noarchive" />\n    <meta name="distribution" content="global" />\n    <meta name="author" content="AlloCine" />\n    <meta name="country" content="France" />\n    <meta name="geo.position" content="48.87078;2.30447" />\n    <meta name="geo.country" content="FR" />\n        <meta name="ICBM" content="48.87078;2.30447" />\n    <meta name="theme-color" content="#FECC00" />\n    <meta name="description" content="A lire sur AlloCiné : Sorti le 15 juin 2005 sur nos écrans, &quot;Batman Begins&quot; ressuscitait l\'Homme Chauve-Souris grâce à Christopher Nolan et Christian Bale, et un projet qui a mis du temps à se concrétiser." />\n    <meta property="og:site_name" content="AlloCiné" />\n    <meta property="og:title" content="15 ans de Batman Begins : comment Christopher Nolan a sauvé l\'Homme Chauve-Souris" />\n    <meta property="og:description" content="Sorti le 15 juin 2005 sur nos écrans, &quot;Batman Begins&quot; ressuscitait l\'Homme Chauve-Souris grâce à Christopher Nolan et Christian Bale, et un projet qui a mis du temps à se concrétiser." />\n    <meta property="og:image" content="http://fr.web.img5.acsta.net/newsv7/20/06/15/15/08/4629294.jpg" />\n    <meta property="og:type" content="article" />\n    <meta property="fb:app_id" content="99197768694" />\n            <meta name="twitter:card" content="summary_large_image" />\n    <meta name="twitter:site" content="@allocine" />\n    <meta name="twitter:title" content="15 ans de Batman Begins : comment Christopher Nolan a sauvé l\'Homme Chauve-Souris" />\n    <meta name="twitter:description" content="Sorti le 15 juin 2005 sur nos écrans, &quot;Batman Begins&quot; ressuscitait l\'Homme Chauve-Souris grâce à Christopher Nolan et Christian Bale, et un projet qui a mis du temps à se concrétiser." />\n    <meta name="twitter:image" content="http://fr.web.img5.acsta.net/newsv7/20/06/15/15/08/4629294.jpg" />\n    \n    \n        <meta name="twitter:app:name:iphone" content="allocine" />\n    <meta name="twitter:app:name:ipad" content="allocine" />\n    <meta name="twitter:app:name:googleplay" content="allocine" />\n    <meta name="twitter:app:url:iphone" content="allocine://open/news?code=18690706" />\n    <meta name="twitter:app:url:ipad" content="allocine://open/news?code=18690706" />\n    <meta name="twitter:app:url:googleplay" content="allocine://open/news?code=18690706" />\n    <meta name="twitter:app:id:iphone" content="351184863" />\n    <meta name="twitter:app:id:ipad" content="351184863" />\n    <meta name="twitter:app:id:googleplay" content="com.allocine.androidapp" />\n    <meta name="apple-itunes-app" content=\'app-id=351184863, app-argument=allocine://open/news?code=18690706\'>\n            <meta property="fb:pages" content="107276450147" />\n                <link rel="preconnect" href="https://assets.allocine.fr" />\n                <link rel="preload" href="https://assets.allocine.fr/skin/font/icon/font-icon-a909e8eb00.woff2" as="font" type="font/woff2" crossorigin />\n\n        <link rel="preload" href="https://assets.allocine.fr/js/website/website-common.faf64ba113c4d2336084.js" as="script" />\n        <link rel="preload" href="https://assets.allocine.fr/js/website/newspage.03505b1fcfbbc7a22377.js" as="script" />\n    \n    <style>article,aside,details,figcaption,figure,foote ...

# %%
soup=Beautifulsoup(resp.content)
