# %%
##url='https://www.producthunt.com/topics/productivity?order=most-upvoted'

# %%
url='https://www.producthunt.com/frontend/graphql'

# %%
##Request Method is Post then ......

# %%
import requests as r
from bs4 import BeautifulSoup
import time

# %%
##soup=BeautifulSoup(r.get(url).content)

# %%
##to select pages in different choosed categories

# %%
topics=['productivity','tech','artificial intelligence']

# %%
##urls=['https://www.producthunt.com/topics/'+i for i in topics]
##to collect data on different topics

# %%
##urls

# %%
##r.get(urls[0]).content

# %%
urls=['https://www.producthunt.com/topics/'+i+'?order=most-upvoted' for i in topics]

# %%
##'+i+'????
##'?order=most-upvoted':to get the most upvoted
##(no idea how to get the less upvoted)

# %%
urls
# Out:
# ['https://www.producthunt.com/topics/productivity?order=most-upvoted',
#  'https://www.producthunt.com/topics/tech?order=most-upvoted',
#  'https://www.producthunt.com/topics/artificial intelligence?order=most-upvoted']

# %%
r.get(urls[0]).content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><title>Productivity topic | Product Hunt</title><link rel="canonical" href="https://www.producthunt.com/topics/productivity"/><meta name="description" content="If time is most precious, this collection of lifehacks is so so precious. Be more productive and optimize your life.. Discover the top 35196 products in Productivity for web, iOS and Android like Startup Stash, Slack, and Startup Pitch Decks"/><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/><meta http-equiv="Content-Language" content="en"/><meta name="theme-color" content="#000000"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"/><meta property="fb:app_id" content="1467820943460899"/><link rel="chrome-webstore-item" href="https://chrome.google.com/webstore/detail/likjafohlgffamccflcidmedfongmkee"/><link rel="apple-touch-icon-precomposed" href="https://assets.producthunt.com/assets/ph-ios-icon-e1733530a1bfc41080db8161823f1ef262cdbbc
# ...

# %%
##BEAUTIFUL is a library which is used to scrap.

# %%
headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
content-length: 286
content-type: application/json
cookie: __cfduid=ddb8065d90ed65b6cfed143582c7e8fa91593276348; first_visit_at=1593276350; first_referer=https://www.google.com/; ajs_anonymous_id=%221643cc46-618d-4dae-8ac1-99f48c1e077b%22; _ga=GA1.2.425330402.1593276351; _gid=GA1.2.247686854.1593276351; visitor_id=31c0c380-c9f0-4932-a0d2-6e7fb0b5f6c8; track_code=ede72163e7; intercom-id-fe4ce68d4a8352909f553b276994db414d33a55c=b43f7b85-fe12-4194-8fb8-b64de4207e0b; intercom-session-fe4ce68d4a8352909f553b276994db414d33a55c=; agreed_cookie_policy=agreed; csrf_token=Tl6ttxxCK6xi%2BPZx%2FLHxviD5ftVkMZvKqruzlWpqFU%2FRqLLtLbigRXOV0RxXWuD1unAilCsrb0grfGIbAWO1uA%3D%3D; _producthunt_session_production=Lzl3NmpmRjUxeFVlK2d0eTB2cVhraXBaa0ZVYkFlOHVBYlNVc1Y3S0VudU1kWHFhUzI0VUZBU1dmY2NjUzJlczNJMTFZN2hpRjhSMkVFVnoyUnFWV3dkUDlCTVlkRU01eTNmYk9Dc083ZGRMcWJZMWl1dEEyazg0L0lkR3NFKzJDb2ZuWWgrVjR1NmFuZk1lM2xQTXpRPT0tLWphN0FIbGFqU081OHJzSGhLVFJOVWc9PQ%3D%3D--e4574b9c682a492f7bb59730746df66fa4f1de5f
origin: https://www.producthunt.com
referer: https://www.producthunt.com/topics/productivity?order=most-upvoted
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36
x-requested-with: XMLHttpRequest"""

# %%
##Header response in networw, XHR
## In copying the header response, i provide information to the server.
##in order to simulate a lambda behavior and not to have the behavior of webscrapper.
##
##Don't forget to erase the 3 first lines.

# %%
##what is r?

# %%
##scrap on productivity but probably on the other pages too (not yet here)
##urls[0] is for productivity category

# %%
soup=BeautifulSoup(r.get(urls[0]).content)

# %%
##reload the webpages, grab the app's names.
##For the moment, there are only 19 apps.

# %%
[i['href'] for i in soup.select('a.link_523b9')]
# Out:
# ['/r/p/164482?ref=topic_page&promo_id=12634',
#  '/posts/startup-stash',
#  '/posts/slack',
#  '/posts/startup-pitch-decks',
#  '/posts/station-3',
#  '/posts/remove-bg',
#  '/posts/notion-2-0',
#  '/posts/coda',
#  '/posts/polymail-2',
#  '/posts/notion-1-0-web-mac-app',
#  '/posts/crello',
#  '/posts/bubble-3',
#  '/posts/humaaans',
#  '/posts/cheatsheet-2',
#  '/posts/google-duplex',
#  '/posts/open-peeps',
#  '/posts/brain-fm',
#  '/posts/hey-62dbfc18-c745-4d86-9a5b-a23a1f4d9eb3',
#  '/posts/make-book',
#  '/posts/whatruns',
#  '/posts/morning-brew-2']

# %%
##headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
##probably to work on all webpages

# %%
url='https://www.producthunt.com/frontend/graphql'

# %%
headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
content-length: 286
content-type: application/json
cookie: __cfduid=ddb8065d90ed65b6cfed143582c7e8fa91593276348; first_visit_at=1593276350; first_referer=https://www.google.com/; ajs_anonymous_id=%221643cc46-618d-4dae-8ac1-99f48c1e077b%22; _ga=GA1.2.425330402.1593276351; _gid=GA1.2.247686854.1593276351; visitor_id=31c0c380-c9f0-4932-a0d2-6e7fb0b5f6c8; track_code=ede72163e7; intercom-id-fe4ce68d4a8352909f553b276994db414d33a55c=b43f7b85-fe12-4194-8fb8-b64de4207e0b; intercom-session-fe4ce68d4a8352909f553b276994db414d33a55c=; agreed_cookie_policy=agreed; csrf_token=Tl6ttxxCK6xi%2BPZx%2FLHxviD5ftVkMZvKqruzlWpqFU%2FRqLLtLbigRXOV0RxXWuD1unAilCsrb0grfGIbAWO1uA%3D%3D; _producthunt_session_production=Lzl3NmpmRjUxeFVlK2d0eTB2cVhraXBaa0ZVYkFlOHVBYlNVc1Y3S0VudU1kWHFhUzI0VUZBU1dmY2NjUzJlczNJMTFZN2hpRjhSMkVFVnoyUnFWV3dkUDlCTVlkRU01eTNmYk9Dc083ZGRMcWJZMWl1dEEyazg0L0lkR3NFKzJDb2ZuWWgrVjR1NmFuZk1lM2xQTXpRPT0tLWphN0FIbGFqU081OHJzSGhLVFJOVWc9PQ%3D%3D--e4574b9c682a492f7bb59730746df66fa4f1de5f
origin: https://www.producthunt.com
referer: https://www.producthunt.com/topics/productivity?order=most-upvoted
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36
x-requested-with: XMLHttpRequest"""

# %%
##to erase ": " and  ('\n') 
##split in panda

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
##to find payload in request payload variable in firefox

# %%
payload="""{"operationName":"TopicsSidebarQuery","variables":{},"query":"query TopicsSidebarQuery {\n  viewer {\n    ...SidebarCardsViewer\n    __typename\n  }\n}\n\nfragment SidebarCardsViewer on Viewer {\n  id\n  has_newsletter_subscription\n  can_claim_aws_credits\n  email\n  __typename\n}\n"}"""

# %%
r.post(url, headers=headers, data=payload)
# Out:
# <Response [200]>

# %%
#wtf?

# %%
r.post(url, headers=headers, data=payload).content
# Out:
# b'\x83\x0b\x80{"data":{"viewer":null}}\x03'

# %%
len([i['href'] for i in soup.select('a.link_523b9')])
# Out:
# 21

# %%
##Now I get 21 apps. (to switch the second page)

# %%
urls=['https://www.producthunt.com/topics/'+i+'?order=most-upvoted' for i in topics]

# %%
urls
# Out:
# ['https://www.producthunt.com/topics/productivity?order=most-upvoted',
#  'https://www.producthunt.com/topics/tech?order=most-upvoted',
#  'https://www.producthunt.com/topics/artificial intelligence?order=most-upvoted']

# %%
soup=BeautifulSoup(r.get(urls[0]).content)

# %%
lol=[i['href'] for i in soup.select('a.link_523b9')]

# %%
lol
# Out:
# ['/r/p/164482?ref=topic_page&promo_id=12634',
#  '/posts/startup-stash',
#  '/posts/slack',
#  '/posts/startup-pitch-decks',
#  '/posts/station-3',
#  '/posts/remove-bg',
#  '/posts/notion-2-0',
#  '/posts/coda',
#  '/posts/polymail-2',
#  '/posts/notion-1-0-web-mac-app',
#  '/posts/crello',
#  '/posts/bubble-3',
#  '/posts/humaaans',
#  '/posts/cheatsheet-2',
#  '/posts/google-duplex',
#  '/posts/open-peeps',
#  '/posts/brain-fm',
#  '/posts/hey-62dbfc18-c745-4d86-9a5b-a23a1f4d9eb3',
#  '/posts/make-book',
#  '/posts/whatruns',
#  '/posts/morning-brew-2']

# %%
urls=['https://www.producthunt.com/topics/'+i+'?order=most-upvoted' for i in topics]

# %%
urls
# Out:
# ['https://www.producthunt.com/topics/productivity?order=most-upvoted',
#  'https://www.producthunt.com/topics/tech?order=most-upvoted',
#  'https://www.producthunt.com/topics/artificial intelligence?order=most-upvoted']

# %%
##The loop gives access to all the apps.

# %%
lol=[]
for url in urls:
    soup=BeautifulSoup(r.get(url).content)
    lol.extend([i['href'] for i in soup.select('a.link_523b9')])
    print('Link', url, 'is done')
lol
# Out:
# Link https://www.producthunt.com/topics/productivity?order=most-upvoted is done
# Link https://www.producthunt.com/topics/tech?order=most-upvoted is done
# Link https://www.producthunt.com/topics/artificial intelligence?order=most-upvoted is done
# ['/r/p/164482?ref=topic_page&promo_id=12634',
#  '/posts/startup-stash',
#  '/posts/slack',
#  '/posts/startup-pitch-decks',
#  '/posts/station-3',
#  '/posts/remove-bg',
#  '/posts/notion-2-0',
#  '/posts/coda',
#  '/posts/polymail-2',
#  '/posts/notion-1-0-web-mac-app',
#  '/posts/crello',
#  '/posts/bubble-3',
#  '/posts/humaaans',
#  '/posts/cheatsheet-2',
#  '/posts/google-duplex',
#  '/posts/open-peeps',
#  '/posts/brain-fm',
#  '/posts/hey-62dbfc18-c745-4d86-9a5b-a23a1f4d9eb3',
#  '/posts/make-book',
#  '/posts/whatruns',
#  '/posts/morning-brew-2',
#  '/posts/startup-stash',
#  '/posts/slack',
#  '/posts/startup-pitch-decks',
#  '/posts/pexels-2-0',
#  '/posts/station-3',
#  '/posts/hotjar',
#  '/posts/good-email-copy',
# ...

# %%
lol=[]
for url in urls:
    soup=BeautifulSoup(r.get(url).content)
    lol.extend([i['href'] for i in soup.select('a.link_523b9')])
    print('Link', url, 'is done')
len(lol)
# Out:
# Link https://www.producthunt.com/topics/productivity?order=most-upvoted is done
# Link https://www.producthunt.com/topics/tech?order=most-upvoted is done
# Link https://www.producthunt.com/topics/artificial intelligence?order=most-upvoted is done
# 46

# %%
lol=['https://www.producthunt.com'+i for i in lol if i.startswith('/posts')]

# %%
lol[0]
# Out:
# 'https://www.producthunt.com/posts/startup-stash'

# %%
##lol=['https://www.producthunt.com'+i for i in lol if i.startswith('/posts')]

# %%
##lol[1]

# %%
##soup=BeautifulSoup(r.get(lol[0].content)

# %%
##upvotes=soup.select('span.bigButtonCount_10448')

# %%
##upvotes

# %%
upvotes=int(soup.select('span.bigButtonCount_10448')[0].text.replace(',',''))
# Out:
# ----------------------------------------------------------
# IndexError               Traceback (most recent call last)
# <ipython-input-52-ada3f99cf54a> in <module>()
# ----> 1 upvotes=int(soup.select('span.bigButtonCount_10448')[0].text.replace(',',''))
#
# IndexError: list index out of range

# %%
company_name=soup.select('h1')[0].text

# %%
intro=soup.select('h2')[0].text
# Out:
# ----------------------------------------------------------
# IndexError               Traceback (most recent call last)
# <ipython-input-54-0b158ffe9bb2> in <module>()
# ----> 1 intro=soup.select('h2')[0].text
#
# IndexError: list index out of range

# %%
descr=soup.select('div.description_10eff')[0].text
# Out:
# ----------------------------------------------------------
# IndexError               Traceback (most recent call last)
# <ipython-input-55-2f1ca49ccb62> in <module>()
# ----> 1 descr=soup.select('div.description_10eff')[0].text
#
# IndexError: list index out of range

# %%
num_reviews=soup.select('div.reviewContainer_48ace"><div class="actions_d65ee"><span class="font_9d927 small_231df semiBold_e201b lineHeight_042f1 underline_57d3c">Would you recommend this product?</span><button class="button_30e5c smallSize_5216f simpleVariant_8a863 positive_faa82" data-test="positive-sentiment-button"><span class="font_9d927 xSmall_1a46e semiBold_e201b buttonContainer_b6eb3 lineHeight_042f1 underline_57d3c uppercase_a49b4"><svg width="22" height="22" viewBox="0 0 22 22" xmlns="http://www.w3.org/2000/svg"><g fill="#66BE00"><path d="M11 20.975c-5.5 0-9.975-4.475-9.975-9.975S5.5 1.025 11 1.025 20.975 5.5 20.975 11 16.5 20.975 11 20.975zM10.999 1.52c-5.227 0-9.48 4.252-9.48 9.48 0 5.228 4.253 9.48 9.48 9.48s9.48-4.252 9.48-9.48c0-5.228-4.253-9.48-9.48-9.48z" stroke="#7CBC00"></path><path d="M11.054 15.43a6.555 6.555 0 0 1-4.42-1.727.477.477 0 0 1 .648-.698 5.589 5.589 0 0 0 3.772 1.47 5.595 5.595 0 0 0 3.674-1.386.482.482 0 0 1 .673.04.482.482 0 0 1-.04.673 6.467 6.467 0 0 1-4.307 1.629zm5.585-5.682c.099.064.232-.01.232-.13v-.004a1.288 1.288 0 0 0-2.574 0v.005c0 .119.134.188.233.129a1.995 1.995 0 0 1 1.05-.298 1.92 1.92 0 0 1 1.059.298zm-9.174 0c.1.064.233-.01.233-.13v-.004a1.288 1.288 0 0 0-2.574 0v.005c0 .119.133.188.232.129a1.995 1.995 0 0 1 1.05-.298 1.93 1.93 0 0 1 1.06.298z"></path></g></svg>Yes</span></button><button class="button_30e5c smallSize_5216f simpleVariant_8a863 negative_8ed4d" data-test="negative-sentiment-button"><span class="font_9d927 xSmall_1a46e semiBold_e201b buttonContainer_b6eb3 lineHeight_042f1 underline_57d3c uppercase_a49b4"><svg width="22" height="22" viewBox="0 0 22 22" xmlns="http://www.w3.org/2000/svg"><g fill="#F95353"><path d="M11 20.975c-5.5 0-9.975-4.475-9.975-9.975S5.5 1.025 11 1.025 20.975 5.5 20.975 11 16.5 20.975 11 20.975zM11 1.52c-5.228 0-9.48 4.252-9.48 9.48 0 5.228 4.252 9.48 9.48 9.48 5.228 0 9.48-4.252 9.48-9.48 0-5.228-4.252-9.48-9.48-9.48z" stroke="#F95353"></path><path d="M4.317 9.97a.339.339 0 0 1-.164-.044.32.32 0 0 1-.108-.436c.534-.9 1.505-1.5 2.435-1.48a.319.319 0 0 1 .312.322.318.318 0 0 1-.317.312h-.03c-.697 0-1.44.465-1.85 1.168a.335.335 0 0 1-.278.158zm13.366 0a.315.315 0 0 1-.272-.153c-.416-.703-1.159-1.168-1.857-1.168h-.03a.315.315 0 0 1-.316-.312.316.316 0 0 1 .312-.322c.916-.02 1.9.58 2.435 1.48.09.149.04.347-.113.436a.341.341 0 0 1-.159.04zm-3.099 1.565a.093.093 0 0 0-.134.099c.12.584.694 1.03 1.387 1.03.698 0 1.272-.446 1.39-1.03.016-.075-.064-.139-.133-.1a2.55 2.55 0 0 1-1.257.322 2.585 2.585 0 0 1-1.253-.321zm-9.678 0c-.07-.035-.149.024-.134.099.114.584.693 1.03 1.391 1.03.698 0 1.273-.446 1.387-1.03.014-.075-.065-.139-.134-.1a2.55 2.55 0 0 1-1.258.322 2.6 2.6 0 0 1-1.252-.321zm9.5 5.064c.297.05.5-.297.302-.525-.861-1-2.203-1.638-3.708-1.638-1.505 0-2.847.643-3.708 1.638-.198.228.005.575.302.525A21.819 21.819 0 0 1 11 16.342c1.228.005 2.381.094 3.406.257z"></path></g></svg>No</span></button></div><div><span class="font_9d927 grey_bbe43 small_231df normal_d2e66 lineHeight_042f1 underline_57d3c">135 Reviews</span><span class="font_9d927 small_231df semiBold_e201b rating_9e6bb lineHeight_042f1 underline_57d3c')
# Out:
# ----------------------------------------------------------
# ValueError               Traceback (most recent call last)
# <ipython-input-56-0e4a8a9935a7> in <module>()
# ...

# %%
[i.text for i in soup.select('div[data-test]')]
# Out:
# ['Trendy 404sA set of creative templates for your 404s1189\xa034Design Tools',
#  '',
#  '404 IllustrationsOpen-source catchy illustrations for perfect error pages1026\xa041Design Tools',
#  '',
#  'The Wayback Machine 404 FixerAuto-magically hunt down cached web pages if you get 404s142\xa00Chrome Extensions',
#  '',
#  'Intelligent 404Stop losing customers to broken links with AI powered 404s142\xa010User Experience',
#  '',
#  "Space Invaders + #drumpf 404 PageLazy Eight's 404 page is Space Invaders + #drumpf epicness. 85\xa08Funny",
#  '']

# %%
[i.text for i in soup.select('div[data-test] div.font_9d927.small_231df')]
# Out:
# []

# %%
comments=[i.text for i in soup.select('div[data-test] div.font_9d927.small_231df')]

# %%
avgscore=soup.select('div.reviewContainer_48ace>div>span.font_9d927.grey_bbe43.small_231df.normal_d2e66.lineHeight_042f1.underline_57d3c+span')

# %%
data=[]
for ix, i in enumerate(lol):
    output=scrape_info(i)
    data.append(output)
    if ix%5==0:
        time.sleep(2)
