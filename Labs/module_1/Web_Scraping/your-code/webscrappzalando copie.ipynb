sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36
x-xsrf-token: AAAAABWVHS3DxZWItBWp7hn4b8CgRsVNSOiW3vJNlENQdVQN5yasINgiu9ebHeHzRGKEBrpQ3fGMyhZXQSbVz3lkf0liNJZ3ooam9vpJr1Ykvi594dmaVMJ2gdG96wxd5uFaAnaNr_nqPLnGQ1uvlyQ=
x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22promo-enfant%22%5D%2C%22previous_selected_filters%22%3A%5B%5D%2C%22preselected_filters%22%3A%5B%5D%7D
x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22eager-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-371f3b5e-fc7b-472a-ba5b-5a94535e515f%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""

# %%
headers=dict(i.split(': ') for i in h.split('\n'))

# %%
resp=r.get(new_url, headers=headers)

# %%
resp.json()
# Out:
# {'total_count': 26807,
#  'pagination': {'page_count': 320, 'current_page': 5, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'F5713G066-K11',
#    'name': 'Chaussons - dark blue',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '23,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['31', '32', '33', '34', '35'],
#    'url_key': 'friboo-mules-dark-blue-f5713g066-k11',
#    'media': [{'path': 'F5/71/3G/06/6K/11/F5713G066-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Friboo',
#    'is_premium': False,
#    'family_articles': [{'sku': 'F5713G066-K11',
#      'url_key': 'friboo-mules-dark-blue-f5713g066-k11',
#      'media': [{'path': 'F5/71/3G/06/6K/11/F5713G066-K11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
# ...
