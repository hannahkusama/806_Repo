# %%
##content-txt review-card-content

# %%
url='http://www.allocine.fr/film/fichefilm_gen_cfilm=247518.html'

# %%
import requests as r

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(r.get(url).content)

# %%
resp = r.get(url)

# %%
resp.text
# Out:
# '<!DOCTYPE html>\n<html lang="fr">\n<head>\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n    <meta name="robots" content="index,follow,max-snippet:-1,max-image-preview:standard" />\n        <title>Le Capital au XXIe siècle - film 2019 - AlloCiné</title>\n    <meta name="keywords" content="" />\n    <meta name="Googlebot" content="noarchive" />\n    <meta name="distribution" content="global" />\n    <meta name="author" content="AlloCine" />\n    <meta name="country" content="France" />\n    <meta name="geo.position" content="48.87078;2.30447" />\n    <meta name="geo.country" content="FR" />\n        <meta name="ICBM" content="48.87078;2.30447" />\n    <meta name="theme-color" content="#FECC00" />\n    <meta name="description" content="Le Capital au XXIe siècle est un film réalisé par Justin Pemb
# ...

# %%
##len([i['href'] for i in soup.select(section.section[1])])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-dfa72096271a> in <module>()
# ----> 1 len([i['href'] for i in soup.select(section.section[1])])
#
# NameError: name 'section' is not defined

# %%
##len([i['div.content-txt review-card-content'] for i in soup.select('section nd___highlighted')])
# Out:
# 0

# %%
##len([i['div'] for i in soup.select('section nd___highlighted')])
# Out:
# 0

# %%
##soup.select('div.content-txt review-card-content')
# Out:
# []

# %%
soup.select()

# %%
[i['src'] for i in soup.select('img')]
# Out:
# ['http://fr.web.img3.acsta.net/commons/v9/allocine/logo-custom/logo-allezocine-220x37.gif',
#  'http://fr.web.img6.acsta.net/commons/v9/allocine/logo-custom/logo-allezocine.svg',
#  '',
#  '',
#  'http://fr.web.img5.acsta.net/c_215_290/pictures/20/02/12/09/31/2868343.jpg',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...']
